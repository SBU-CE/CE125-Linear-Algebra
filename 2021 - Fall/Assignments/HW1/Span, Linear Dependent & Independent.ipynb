# %% [markdown]
# ## Part 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[1, -1],
              [2, 2]])

# %%
origin = np.array([[0, 0],
                   [0, 0]])

# %%
x_min, x_max = -5, 5
y_min, y_max = -5, 5

scale = 1

# %%
def draw_grid(x_min, x_max, y_min, y_max):
    
    fig = plt.figure()

    # 1×1 grid, first subplot
    ax = fig.add_subplot(1, 1, 1) 

    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)

    grid_x_ticks = np.arange(x_min, x_max + 1, 1)
    grid_y_ticks = np.arange(y_min, y_max + 1, 1)

    ax.set_xticks(grid_x_ticks)
    ax.set_yticks(grid_y_ticks)

    ax.grid()
    
    return ax

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

plt.show()

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

ax.quiver(*origin, *A, scale=scale, scale_units='xy', angles='xy', color=['g', 'r'])

plt.show()

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

scaler = np.arange(-5., 5., .001)
scaler = scaler.reshape(scaler.shape[0], 1)

np.random.shuffle(scaler)
V1 = scaler*A[:, 0]

np.random.shuffle(scaler)
V2 = scaler*A[:, 1]

span = V1 + V2

ax.plot(span[:, 0], span[:, 1], 'b.')
    
ax.quiver(*origin, *A, scale=scale, scale_units='xy', angles='xy', color=['g', 'r'])

plt.show()

# %% [markdown]
# ## Part 2

# %%
B = np.array([[1, -1],
              [2, -2]])

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

ax.quiver(*origin, *B, scale=scale, scale_units='xy', angles='xy', color=['g', 'r'])

plt.show()

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

scaler = np.arange(-5., 5., .01)
scaler = scaler.reshape(scaler.shape[0], 1)

np.random.shuffle(scaler)
V1 = scaler*B[:, 0]

np.random.shuffle(scaler)
V2 = scaler*B[:, 1]

span = V1 + V2

ax.plot(span[:, 0], span[:, 1], 'b.')
    
ax.quiver(*origin, *B, scale=scale, scale_units='xy', angles='xy', color=['g', 'r'])

plt.show()

# %% [markdown]
# ## Part 3

# %%
C = np.array([[0, 0],
              [0, 0]])

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

ax.quiver(*origin, *C, scale=scale, scale_units='xy', angles ='xy', color=['g', 'r'])

plt.show()

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

scaler = np.arange(-5., 5., .01)
scaler = scaler.reshape(scaler.shape[0], 1)

np.random.shuffle(scaler)
V1 = scaler*C[:, 0]

np.random.shuffle(scaler)
V2 = scaler*C[:, 1]

span = V1 + V2

ax.plot(span[:, 0], span[:, 1], 'b.')
    
ax.quiver(*origin, *C, scale=scale, scale_units='xy', angles='xy', color=['g', 'r'])

plt.show()

# %% [markdown]
# ## Extra

# %%
A = np.array([[1, -1],
              [2, 2]])

# %%
print(A[0, 0])

print(A[1, 0])

print(A[0, 1])

print(A[1, 1])

print(A[0, :])

print(A[1, :])

print(A[:, 0])

print(A[:, 1])

print(A[:])
# Out:
# 1
# 2
# -1
# 2
# [ 1 -1]
# [2 2]
# [1 2]
# [-1  2]
# [[ 1 -1]
#  [ 2  2]]

# %%
def sum_args(arg1, arg2, arg3):
    
    sum_args = arg1 + arg2 + arg3
    
    return sum_args

# %%
sum_args(1, 2, 3)
# Out:
# 6

# %%
my_list = [1, 2, 3]

sum_args(*my_list)
# Out:
# 6

# %% [markdown]
# ### Draw Vectors

# %%
origin_x = 0
origin_y = 1

vector_x = 1
vector_y = 3

ax = draw_grid(x_min, x_max, y_min, y_max)

ax.quiver(origin_x, origin_y, vector_x, vector_y, scale=scale, scale_units='xy', angles ='xy', color='r')

plt.show()

# %%
origin = [0, 1]

vector = [1, 3]

ax = draw_grid(x_min, x_max, y_min, y_max)

ax.quiver(*origin, *vector, scale=scale, scale_units='xy', angles ='xy', color='b')

plt.show()

# %%
origin = np.array([[0, 0, -1],
                   [0, 0, -1]])

vector = np.array([[1, 2, 3],
                   [3, 4, 3]])

color = ['b', 'y', 'r']

ax = draw_grid(x_min, x_max, y_min, y_max)

ax.quiver(*origin, *vector, scale=scale, scale_units='xy', angles='xy', color=color)

plt.show()

# %%
origin = np.array([[0, 0],
                   [0, 0],
                   [-1, -1]])

vector = np.array([[1, 3],
                   [2, 4],
                   [3, 3]])

color = ['b', 'y', 'r']

ax = draw_grid(x_min, x_max, y_min, y_max)

ax.quiver(origin[:, 0], origin[:, 1],  vector[:, 0], vector[:, 1], scale=scale, scale_units='xy', angles='xy', color=color)

plt.show()

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

ax.quiver(origin[0, :], origin[1, :], A[0, :], A[1, :], scale=scale, scale_units='xy', angles ='xy', color=['g', 'r'])

plt.show()

# %% [markdown]
# ### Linear Combination

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

scaler = np.arange(-10., 10., .1)
scaler = scaler.reshape(scaler.shape[0], 1)

added_vectors = A[:, 0] + scaler*A[:, 1]

ax.plot(added_vectors[:, 0], added_vectors[:, 1], 'b-')
    
ax.quiver(*origin, *A, scale=scale, scale_units='xy', angles='xy', color=['g', 'r'])

plt.show()

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

scaler = np.arange(-10., 10., .1)
scaler = scaler.reshape(scaler.shape[0], 1)

added_vectors = scaler*A[:, 0] + A[:, 1]

ax.plot(added_vectors[:, 0], added_vectors[:, 1], 'b-')
    
ax.quiver(*origin, *A, scale=scale, scale_units='xy', angles='xy', color=['g', 'r'])

plt.show()

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

scaler = np.arange(-10., 10., .1)
scaler = scaler.reshape(scaler.shape[0], 1)

added_vector_a = A[:, 0] + scaler*A[:, 1]
added_vector_b = scaler*A[:, 0] + A[:, 1]

ax.plot(added_vector_a[:, 0], added_vector_a[:, 1], 'b-')
ax.plot(added_vector_b[:, 0], added_vector_b[:, 1], 'b-')
    
ax.quiver(*origin, *A, scale=scale, scale_units='xy', angles='xy', color=['g', 'r'])

plt.show()

# %%
ax = draw_grid(x_min, x_max, y_min, y_max)

scaler = np.arange(-10., 10., .1)
scaler = scaler.reshape(scaler.shape[0], 1)

i_tr = scaler*A[:, 0]
j_tr = scaler*A[:, 1]

ax.plot(i_tr[:, 0], i_tr[:, 1], 'b-')
ax.plot(j_tr[:, 0], j_tr[:, 1], 'b-')
    
ax.quiver(*origin, *A, scale=scale, scale_units='xy', angles='xy', color=['g', 'r'])

plt.show()
